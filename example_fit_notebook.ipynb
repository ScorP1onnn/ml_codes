# %%
from sculptor import speconed as sod
from astropy.io import fits
import astropy.units as units
import matplotlib.pyplot as plt

# %%
#pip install simplejson

# %%
file = "J030341.04-002321.8_0.fits"
hdu = fits.open(file)

# %%
wavelength = 10**hdu[1].data['loglam']
flux = hdu[1].data['flux']
inv_var = hdu[1].data['ivar']

# %%
plt.plot(wavelength,flux)

# %%
hdr =  hdu[0].header
hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# TAI     =        4477028053.74 / 1st row - Number of seconds since Nov 17 1858
# RA      =            45.787818 / 1st row - Right ascension of telescope boresigh
# DEC     =           -0.017770  / 1st row - Declination of telescope boresight (d
# EQUINOX =              2000.00 /
# RADECSYS= 'FK5     '           /
# TAIHMS  = '10:36:49.28'        / 1st row - TAI time (HH:MM:SS.SS) (TAI-UT = appr
# TIMESYS = 'tai     '           / TAI, not UTC
# MJD     =                51817 / MJD of observation
# MJDLIST = '51817   '           /
# VERSION = 'v3_18_4_1'          / version of IOP
# CAMVER  = 'SPEC2 v4_5'         / Camera code version
# OBSERVER= 'sjnk    '
# OBSCOMM = 'science '
# TELESCOP= 'SDSS 2.5-M'         / Sloan Digital Sky Survey
# BESTEXP =                 6799 /
# NEXP_B1 =                    3 / b1 camera number of exposures
# NEXP_R1 =                    3 / r1 camera number of exposures
# EXPT_B1 =              2700.00 / b1 camera exposure time (seconds)
# EXPT_R1 =              2700.00 / r1 camera exposure time (seconds)
# EXPTIME =              2700.00 / Minimum of exposure times for all cameras
# SPCOADD = 'Sun Mar  2 17:31:46 2008' / SPCOADD finished
# FLAVOR  = 'science '           / Flavor of this sequence (e.g., dome flat, etc.)
# QUALITY = 'excellent'          / night/image quality
# RADEG   = 4.57870900000000E+01 / Right Ascension. (degrees)
# DECDEG  = -1.6838270000000E-02 / Declination. (degrees)
# PLATEID =                  411 / Plate Id
# TILEID  =                  200 / Tile Id
# CARTID  =                    8 /Cartridge used in this plugging
# MAPID   =              5181701 / Map Id
# NAME    = '0411-51817-01'      / Name of target; PlateId-MJD-Mapper ReRun
# COLBIN  =                    1 / Binning factor perpendicular to the columns
# ROWBIN  =                    1 / Binning factor perpendicular to the rows
# PROGRAM = 'binning 1   1 '     / Identifying name for CCD program
# SECFOCUS= -1.5000000000000E+02 / Secondary Mirror Position as reported by TCC
# GUIDEIMG= '/data/spectro/guider/gimg0389.fits' / Last archived guider image
# WTIME   =        970310795.000 / weatherData(timeStamp)
# AIRTEMP =        12.0666666667 / weatherData(airtemp)
# DEWPOINT=       -4.83333333333 / weatherData(dewpoint)
# DEWDEP  =        16.8333333333 / weatherData(dewpointDep)
# DUSTA   =        28132.3333333 / weatherData(dusta)
# DUSTB   =        281.000000000 / weatherData(dustb)
# DUSTC   =        29288.0000000 / weatherData(dustc)
# DUSTD   =        315.333333333 / weatherData(dustd)
# GUSTD   = 1.83100000000000E+02 / weatherData(gustd)
# GUSTS   =        6.56666666667 / weatherData(gusts)
# HUMIDITY=        30.4333333333 / weatherData(humidity)
# HUMIDOUT=        29.6666666667 / weatherData(humidout)
# PRESSURE=        21.5800000000 / weatherData(pressure)
# WINDD   =        198.400000000 / weatherData(windd)
# WINDS   =        5.66666666667 / weatherData(winds)
# TEMP01  =       -93.7500000000 / CCD 01 Temperature
# TEMP02  =       -93.2300000000 / CCD 02 Temperature
# TEMP03  =       -92.4500000000 / CCD 03 Temperature
# TEMP04  =       -92.9700000000 / CCD 04 Temperature
# VERSIDL = '6.3     '           / Version of IDL
# VERSUTIL= 'v5_3_0  '           / Version of idlutils
# VERSREAD= 'v5_3_12 '           / Version of idlspec2d for pre-processing raw dat
# VERS2D  = 'v5_3_12 '           / Version of idlspec2d for 2D reduction
# VERSCOMB= 'v5_3_12 '           / Version of idlspec2d for combining multiple spe
# VERSLOG = 'fermi-CVS 03/02/08' / Version of SPECLOG product
# VERSFLAT= 'v1_7    '           / Version of SPECFLAT product
# OPBC    = 'opBC-51813.par'     /
# OPCONFIG= 'opConfig-50000.par' /
# OPECALIB= 'opECalib-51577.par' /
# PLUGFILE= 'plPlugMapM-0411-51817-01.par' /
# HELIO_RV=       -16.1715747810 / Heliocentric correction (added to velocities)
# VACUUM  =                    T / Wavelengths are in vacuum
# SFLATTEN=                    T / Superflat has been applied
# PSFSKY  =                    3 / Order of PSF skysubtraction
# SKYCHI2 =        1.12341559017 / Mean chi^2 of sky-subtraction
# SCHI2MIN=        1.03042602624 /
# SCHI2MAX=        1.24664352066 /
# PREJECT =             0.200000 / Profile area rejection threshold
# SPEC1_G =              21.0270 /(S/N)^2 for spec  1 at mag 20.20
# SPEC1_R =              35.2887 /(S/N)^2 for spec  1 at mag 20.25
# SPEC1_I =              36.1768 /(S/N)^2 for spec  1 at mag 19.90
# SPEC2_G =              21.8766 /(S/N)^2 for spec  2 at mag 20.20
# SPEC2_R =              21.4866 /(S/N)^2 for spec  2 at mag 20.25
# SPEC2_I =              23.4558 /(S/N)^2 for spec  2 at mag 19.90
# NSTD    =                   16 / Number of (good) std stars
# GOFFSTD =           -0.0269232 / Spectrophoto offset for std stars in G-band
# GRMSSTD =            0.0567338 / Spectrophoto RMS for std stars in G-band
# ROFFSTD =           -0.0266981 / Spectrophoto offset for std stars in R-band
# RRMSSTD =            0.0269613 / Spectrophoto RMS for std stars in R-band
# IOFFSTD =           -0.0221386 / Spectrophoto offset for std stars in I-band
# IRMSSTD =            0.0326690 / Spectrophoto RMS for std stars in I-band
# GROFFSTD=           -0.0165491 / Spectrophoto offset for std stars in (GR)
# GRRMSSTD=            0.0440112 / Spectrophoto RMS for std stars in (GR)
# RIOFFSTD=           -0.0109558 / Spectrophoto offset for std stars in (RI)
# RIRMSSTD=            0.0305272 / Spectrophoto RMS for std stars in (RI)
# NGAL    =                  412 / Number of (good) main galaxies
# GOFFGAL =           0.00819969 / Spectrophoto offset for main galaxies in G-band
# GRMSGAL =            0.0661735 / Spectrophoto RMS for main galaxies in G-band
# ROFFGAL =          0.000925064 / Spectrophoto offset for main galaxies in R-band
# RRMSGAL =            0.0608323 / Spectrophoto RMS for main galaxies in R-band
# IOFFGAL =          0.000127792 / Spectrophoto offset for main galaxies in I-band
# IRMSGAL =            0.0577229 / Spectrophoto RMS for main galaxies in I-band
# GROFFGAL=           0.00353050 / Spectrophoto offset for main galaxies in (GR)
# GRRMSGAL=            0.0369608 / Spectrophoto RMS for main galaxies in (GR)
# RIOFFGAL=           0.00189018 / Spectrophoto offset for main galaxies in (RI)
# RIRMSGAL=            0.0219187 / Spectrophoto RMS for main galaxies in (RI)
# LOWREJ  =                    5 / Extraction: low rejection
# HIGHREJ =                    8 / Extraction: high rejection
# SCATPOLY=                    0 / Extraction: Order of scattered light polynomial
# PROFTYPE=                    3 / Extraction profile: 1=Gaussian
# NFITPOLY=                    1 / Extraction: Number of parameters in each profil
# XCHI2   =              1.23002 / Extraction: Mean chi^2
# XCHI2MIN=              1.08400 /
# XCHI2MAX=              1.38649 /
# SHIFTGUE=   -0.000812781513105 /
# SHIFT   =       -1.00058111599 /Angstroms, at 4000AA
# SHIFTERR=        4.78599193358 /
# NWORDER =                    2 / Linear-log10 coefficients
# WFITTYPE= 'LOG-LINEAR'         / Linear-log10 dispersion
# COEFF0  =        3.57860000000 / Central wavelength (log10) of first pixel
# COEFF1  =    0.000100000000000 / Log10 dispersion per pixel
# FBADPIX =            0.0202470 / Fraction of bad pixels
# FBADPIX1=            0.0160450 / Fraction of bad pixels on spectro-1
# FBADPIX2=            0.0244490 / Fraction of bad pixels on spectro-2
# WAT0_001= 'system=linear'      /
# WAT1_001= 'wtype=linear label=Wavelength units=Angstroms' /
# DC-FLAG =                    1 / Log-linear flag
# BUNIT   = '1E-17 erg/cm^2/s/Ang' /
# PLUG_RA =            45.921035 / RA of object [deg]
# PLUG_DEC=          -0.38939477 / dec of object [deg]
# SPEC_ID = '    462793270708168704' / Unique object identifier
# FIBERID =                  176 / Fiber number (1-640)
# NEXP    =                    6 / Number of individual exposures
# EXPID01 = 'b1-00006798-00006802-00006803'
# EXPID02 = 'b1-00006799-00006802-00006803'
# EXPID03 = 'b1-00006800-00006802-00006803'
# EXPID04 = 'r1-00006798-00006802-00006803'
# EXPID05 = 'r1-00006799-00006802-00006803'
# EXPID06 = 'r1-00006800-00006802-00006803'

# %%
hdr['BUNIT'], hdr['WAT1_001']
flux_unit = 1e-17 * units.erg/units.s/units.cm**2/units.AA
wave_unit = 1.*units.AA

# %%
spec = sod.SpecOneD(dispersion=wavelength, fluxden = flux, fluxden_ivar=inv_var, fluxden_unit=flux_unit,dispersion_unit=wave_unit, header=hdr)

# %%
spec.plot()

# %%
#spec.convert_spectral_units(1*units.AA,1*units.mJy)

# %%
spec.plot(ymin=0.,ymax=1.2)

# %%
spec.trim_dispersion([5500,6000]).plot(ymin=0,ymax=40) #TWo absorption features

# %%
#Binning the spectrum by 10 pixels
spec.plot()
spec.bin_by_npixels(10).plot()

# %%
#Introducing SpecFit and SpecModel classes to model and fit the spectrum
#spec.plot()

from sculptor import specfit as scfit
from sculptor import specmodel as scmod

# %%
redshift = 3.227
fit = scfit.SpecFit(spec, redshift)

# %%
fit.plot()

# %%
#Fitting the Continuum 

#Add continuum model
fit.add_specmodel()

#access the initialized SpecModel object by using the first item in the SpecFit.specmodels list
contmodel = fit.specmodels[0]

#name the model
contmodel.name = 'continuum'

#Define the model name used to fit the continuum
model_name = 'Power Law (2500A)'

# Define the model prefix. It is important to keep track of the prefix to later access this model in the analysis
model_prefix = 'PL_'


# Add the continuum model function and prefix to the SpecModel
contmodel.add_model(model_name, model_prefix)

# %%
#Define wavelength windows which are free from (strong) emission lines to fit the continuum
contmodel.add_wavelength_range_to_fit_mask(8300, 8620)
contmodel.add_wavelength_range_to_fit_mask(7105, 7205)
contmodel.add_wavelength_range_to_fit_mask(5400, 5450)
contmodel.add_wavelength_range_to_fit_mask(5685, 5750)
contmodel.add_wavelength_range_to_fit_mask(6145, 6212)
# Out:
# [INFO] Manual mask range 8300 8620
# [INFO] Manual mask range 7105 7205
# [INFO] Manual mask range 5400 5450
# [INFO] Manual mask range 5685 5750
# [INFO] Manual mask range 6145 6212

# %%
contmodel.plot() #Just to see if the above mask corresponds to the line free channels

# %%
#Now fit the continuum
contmodel.fit()

# %%
#Now let's plot the fit
contmodel.plot()

# %%
fit.plot()

# %%
contmodel.fit_result
# Out:
# <h2>Fit Result</h2> <p>Model: Model(power_law_at_2500, prefix='PL_')</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>13</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>361</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>2</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 485.269850</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.35172660</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 110.793608</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 118.571364</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.93892305</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>PL_z</td><td style='text-align:left'> 3.22700000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>3.227</td><td style='text-align:left'> 3.06565000</td><td style='text-align:left'> 3.38835000</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>PL_amp</td><td style='text-align:left'> 11.9287906</td><td style='text-align:left'> 0.08948221</td><td style='text-align:left'>(0.75%)</td><td style='text-align:left'>1</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>PL_slope</td><td style='text-align:left'>-1.18662939</td><td style='text-align:left'> 0.01747786</td><td style='text-align:left'>(1.47%)</td><td style='text-align:left'>-1.5</td><td style='text-align:left'>-2.50000000</td><td style='text-align:left'>-0.30000000</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>PL_amp</td><td style='text-align:left'>PL_slope</td><td style='text-align:right'>+0.9460</td></tr></table>

# %%
#Let us fit the SiIV, CIV and CIII] lines. First the SiIV line

# %%
# Add the SiIV emission line model
fit.add_specmodel()

# Access the SpecModel object by choosing the second SpecModel object
siiv_model = fit.specmodels[1]
siiv_model.name = 'SiIV_line'

#Add mask to fit the Si IV line
#siiv_model.add_wavelength_range_to_fit_mask(5750, 6150)
siiv_model.add_wavelength_range_to_fit_mask(5790, 5870)
siiv_model.add_wavelength_range_to_fit_mask(5910, 6015)
# Out:
# [INFO] Manual mask range 5790 5870
# [INFO] Manual mask range 5910 6015

# %%
model_name = 'SiIV (2G components)'
model_prefix = None
siiv_model.add_model(model_name, model_prefix)

# %%
siiv_model.model_list
# Out:
# [Model(line_model_gaussian, prefix='SiIV_A_'),
#  Model(line_model_gaussian, prefix='SiIV_B_')]

# %%
siiv_model.params_list[0]
# Out:
# Parameters([('SiIV_A_z', <Parameter 'SiIV_A_z', value=3.227 (fixed), bounds=[3.0656499999999998:3.38835]>), ('SiIV_A_flux', <Parameter 'SiIV_A_flux', value=532.2335097156131, bounds=[0:532233.5097156131]>), ('SiIV_A_cen', <Parameter 'SiIV_A_cen', value=1399.8 (fixed), bounds=[-inf:inf]>), ('SiIV_A_fwhm_km_s', <Parameter 'SiIV_A_fwhm_km_s', value=2500, bounds=[300:20000]>)])

# %%
siiv_model.params_list[1]
# Out:
# Parameters([('SiIV_B_z', <Parameter 'SiIV_B_z', value=3.227 (fixed), bounds=[3.0656499999999998:3.38835]>), ('SiIV_B_flux', <Parameter 'SiIV_B_flux', value=532.2335097156131, bounds=[0:532233.5097156131]>), ('SiIV_B_cen', <Parameter 'SiIV_B_cen', value=1399.8 (fixed), bounds=[-inf:inf]>), ('SiIV_B_fwhm_km_s', <Parameter 'SiIV_B_fwhm_km_s', value=2500, bounds=[300:20000]>)])

# %%
siiv_model.params_list[0]['SiIV_A_z'].vary = True
siiv_model.params_list[1]['SiIV_B_z'].vary = True

# %%
#siiv_model.params_list[0]['SiIV_A_fwhm_km_s'].max = 30000.0000

# %%
# Fit the SiIV SpecModel
siiv_model.fit()

# %%
siiv_model.plot()

# %%
siiv_model.fit_result
# Out:
# <h2>Fit Result</h2> <p>Model: (Model(line_model_gaussian, prefix='SiIV_A_') + Model(line_model_gaussian, prefix='SiIV_B_'))</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>149</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>135</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>6</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 96.1766681</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 0.74555557</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-33.7768780</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-16.3452293</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.69689394</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>SiIV_A_z</td><td style='text-align:left'> 3.21986832</td><td style='text-align:left'> 0.00268481</td><td style='text-align:left'>(0.08%)</td><td style='text-align:left'>3.227</td><td style='text-align:left'> 3.06565000</td><td style='text-align:left'> 3.38835000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>SiIV_A_flux</td><td style='text-align:left'> 479.888277</td><td style='text-align:left'> 297.304797</td><td style='text-align:left'>(61.95%)</td><td style='text-align:left'>532.2335097156131</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 532233.510</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>SiIV_A_cen</td><td style='text-align:left'> 1399.80000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>1399.8</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>SiIV_A_fwhm_km_s</td><td style='text-align:left'> 4499.32048</td><td style='text-align:left'> 1037.04761</td><td style='text-align:left'>(23.05%)</td><td style='text-align:left'>2500</td><td style='text-align:left'> 300.000000</td><td style='text-align:left'> 20000.0000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>SiIV_B_z</td><td style='text-align:left'> 3.18110358</td><td style='text-align:left'> 0.18598595</td><td style='text-align:left'>(5.85%)</td><td style='text-align:left'>3.227</td><td style='text-align:left'> 3.06565000</td><td style='text-align:left'> 3.38835000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>SiIV_B_flux</td><td style='text-align:left'> 875.042907</td><td style='text-align:left'> 1422.77683</td><td style='text-align:left'>(162.60%)</td><td style='text-align:left'>532.2335097156131</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 532233.510</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>SiIV_B_cen</td><td style='text-align:left'> 1399.80000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>1399.8</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>SiIV_B_fwhm_km_s</td><td style='t ...

# %%
#Now the C IV line

fit.add_specmodel()
civ_model = fit.specmodels[2]
civ_model.name = 'CIV_line'
civ_model.add_wavelength_range_to_fit_mask(6340, 6700)
# Out:
# [INFO] Manual mask range 6340 6700

# %%
civ_model.plot()

# %%
model_name = 'CIV (2G components)'
model_prefix = None
civ_model.add_model(model_name, model_prefix, amplitude=10)

# %%
# Make the redshift a variable parameter
civ_model.params_list[0]['CIV_A_z'].vary = True
civ_model.params_list[1]['CIV_B_z'].vary = True

# %%
civ_model.fit()

# %%
civ_model.plot()

# %%
civ_model.fit_result
# Out:
# <h2>Fit Result</h2> <p>Model: (Model(line_model_gaussian, prefix='CIV_A_') + Model(line_model_gaussian, prefix='CIV_B_'))</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>163</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>240</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>6</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 335.850463</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.43525839</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 92.6465009</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 113.530334</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.96546228</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>CIV_A_z</td><td style='text-align:left'> 3.20954158</td><td style='text-align:left'> 6.9492e-04</td><td style='text-align:left'>(0.02%)</td><td style='text-align:left'>3.227</td><td style='text-align:left'> 3.06565000</td><td style='text-align:left'> 3.38835000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>CIV_A_flux</td><td style='text-align:left'> 1293.16022</td><td style='text-align:left'> 175.421942</td><td style='text-align:left'>(13.57%)</td><td style='text-align:left'>100</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 26611675.5</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>CIV_A_cen</td><td style='text-align:left'> 1549.06000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>1549.06</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>CIV_A_fwhm_km_s</td><td style='text-align:left'> 5023.15775</td><td style='text-align:left'> 282.231459</td><td style='text-align:left'>(5.62%)</td><td style='text-align:left'>2500</td><td style='text-align:left'> 300.000000</td><td style='text-align:left'> 20000.0000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>CIV_B_z</td><td style='text-align:left'> 3.21057698</td><td style='text-align:left'> 0.00193665</td><td style='text-align:left'>(0.06%)</td><td style='text-align:left'>3.227</td><td style='text-align:left'> 3.06565000</td><td style='text-align:left'> 3.38835000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>CIV_B_flux</td><td style='text-align:left'> 1713.04859</td><td style='text-align:left'> 126.446604</td><td style='text-align:left'>(7.38%)</td><td style='text-align:left'>100</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 26611675.5</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>CIV_B_cen</td><td style='text-align:left'> 1549.06000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>1549.06</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>CIV_B_fwhm_km_s</td><td style='text-align:left'> 13058.6710</td><td sty ...

# %%
# Add the CIII] complex emission line model

# Add the CIII] complex emission line model
fit.add_specmodel()
ciii_model = fit.specmodels[3]
ciii_model.name = 'CIII]_complex'

ciii_model.add_wavelength_range_to_fit_mask(7800, 8400)

model_name = 'CIII] complex (3G components)'
model_prefix = None
ciii_model.add_model(model_name, model_prefix, amplitude=2)

ciii_model.params_list[0]['CIII_z'].vary = True

# Initial fit
ciii_model.fit()
# Out:
# [INFO] Manual mask range 7800 8400

# %%
ciii_model.plot() #Model has already converged

# %%
# Second fit to make sure the model converged
ciii_model.fit()

# %%
ciii_model.plot()

# %%
#Fitting absorption lines
spec.plot(ymax=40)
spec.trim_dispersion([5600,6000]).plot(ymax=40)
spec.trim_dispersion([5740,5800]).plot(ymax=40) #TWo absorption features

# %%
fit.add_specmodel()
abs_model = fit.specmodels[4]
abs_model.name = 'Abs_lines'

# %%
abs_model.add_wavelength_range_to_fit_mask(5755, 5785)
# Out:
# [INFO] Manual mask range 5755 5785

# %%
abs_model.plot()

# %%
"""
Wait, how did the spectrum y axis change when I introduce a model? Is th continuum subtracted automatically?

That's the only plausable explaination
"""
# Out:
# "\nWait, how did the spectrum y axis change when I introduce a model? Is th continuum subtracted automatically?\n\nThat's the only plausable explaination\n"

# %%
model_name = 'Line model Gaussian'
model_prefix = 'Abs_A'
abs_model.add_model(model_name, model_prefix, amplitude=-20, cenwave=5766, fwhm=200, redshift=0)

model_name = 'Line model Gaussian'
model_prefix = 'Abs_B'
abs_model.add_model(model_name, model_prefix, amplitude=-20, cenwave=5776, fwhm=200, redshift=0)

# %%
abs_model.fit()

# %%
abs_model.plot()

# %%
abs_model.fit_result
# Out:
# <h2>Fit Result</h2> <p>Model: (Model(line_model_gaussian, prefix='Abs_A') + Model(line_model_gaussian, prefix='Abs_B'))</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>57</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>23</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>6</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 30.9731561</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.82195036</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 18.8454137</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 25.6583790</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.96967602</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>Abs_Az</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'></td><td style='text-align:left'>0</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 1.00000000</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>Abs_Aflux</td><td style='text-align:left'>-145.518523</td><td style='text-align:left'> 5.62574244</td><td style='text-align:left'>(3.87%)</td><td style='text-align:left'>100</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>Abs_Acen</td><td style='text-align:left'> 5765.54391</td><td style='text-align:left'> 0.09744490</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>5766</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>Abs_Afwhm_km_s</td><td style='text-align:left'> 313.664667</td><td style='text-align:left'> 14.5497728</td><td style='text-align:left'>(4.64%)</td><td style='text-align:left'>200</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>Abs_Bz</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'></td><td style='text-align:left'>0</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 1.00000000</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>Abs_Bflux</td><td style='text-align:left'>-114.687404</td><td style='text-align:left'> 5.78967876</td><td style='text-align:left'>(5.05%)</td><td style='text-align:left'>100</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>Abs_Bcen</td><td style='text-align:left'> 5775.65618</td><td style='text-align:left'> 0.11159361</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>5776</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>Abs_Bfwhm_km_s</td><td style='text-align:left'> 268.823008</td><td style='text-align:left'> 16.3125562</td><td s ...

# %%
fit.plot() #All fits

# %%
#Save all fit reports
fit.fit(save_results=True)

# %%
! ls
# Out:
# example_fit			   specmodel_2_FitAll_fit_report.txt
# J030341.04-002321.8_0.fits	   specmodel_3_FitAll_fit_report.txt
# specmodel_0_FitAll_fit_report.txt  specmodel_4_FitAll_fit_report.txt
# specmodel_1_FitAll_fit_report.txt  Untitled.ipynb

# %%
! rm *.txt

# %%
! ls
# Out:
# example_fit  J030341.04-002321.8_0.fits  Untitled.ipynb

# %%
"""

Unable to save the notebook using fir.save().

Throws an error "TypeError: Object of type int64 is not JSON serializable"

"""
# Out:
# '\n\nUnable to save the notebook using fir.save().\n\nThrows an error "TypeError: Object of type int64 is not JSON serializable"\n\n'

# %%
#! rm -rf example_fit_notebook

# %%
#Save the SpecFit object
#fit.save('example_fit_notebook')

# %%
#new_fit = scfit.SpecFit()
#new_fit.load('example_fit_notebook')
